# %%
import os
import datetime
import nest_asyncio
nest_asyncio.apply()

# %%
# Set the root path to be able to import modules loacated in the root project
from rootPath_Setup import add_project_root_to_path
add_project_root_to_path()
# Change working directory to the root folder
os.chdir("..")
print("Current Working Directory:", os.getcwd())
# Out:
# Added c:\Users\Anders\Documents\GitHub\daeCrypto_vscode to sys.path
# Current Working Directory: c:\Users\Anders\Documents\GitHub\daeCrypto_vscode

# %%
from data_fetching.fear_greed_data import orchestrate_greed_data_to_db_pipeline

# %%
# Available sources: 'cnn_stocks' 'alt_me_crypto' 'csv_whit3rabbit_stocks'
# Add new sources in /utils/config.yaml
await orchestrate_greed_data_to_db_pipeline('csv_whit3rabbit_stocks')
